# %% [markdown]
# # Employement Statistics
# ### Exploratory Data Analysis(EDA)
# aspiring_minds_employability_outcomes_2015

# %% [markdown]
# <h3> Step 1: </h3> Introduction -> Give a detailed data description and objective.

# %% [markdown]
# The dataset was released by Aspiring Minds from the Aspiring Mind Employment Outcome 2015 (AMEO). The study is primarily limited  only to students with engineering disciplines. The dataset contains the employment outcomes of engineering graduates as dependent variables (Salary, Job Titles, and Job Locations) along with the standardized scores from three different areas – cognitive skills, technical skills and personality skills. The dataset also contains demographic features. The dataset  contains  around  40 independent variables and 4000 data points. The independent variables are both continuous and categorical in nature. The dataset contains a unique identifier for each candidate. <br>
# Our Objective is to perform the EDA on the given data sets and test few claims with the given data set.

# %% [markdown]
# <h3> Step 2: </h3>
# Import the data and display the head, shape and description of the data.

# %%
# Importing important libraries
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\TheWhiteWolf\Desktop\Afif\Innomatics Internship\Data Analysis Tasks\Task1_EDA\employment_stats.xlsx")

# %%
pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)

# %%
df.head()
# Out:
#   Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0      train  203097   420000 2012-06-01              present
# 1      train  579905   500000 2013-09-01              present
# 2      train  810601   325000 2014-06-01              present
# 3      train  267447  1100000 2011-07-01              present
# 4      train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                 Designation    JobCity Gender        DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3
# 1         assistant manager     Indore      m 1989-10-04          85.4
# 2          systems engineer    Chennai      f 1992-08-03          85.0
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6
# 4                       get    Manesar      m 1991-02-27          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# ...

# %%
df.shape
# Out:
# (3998, 39)

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %% [markdown]
# #### Checking for the Missing and Null Values in the data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   int64
#  3   DOJ                    3998 non-null   datetime64[ns]
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   datetime64[ns]
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# ...

# %% [markdown]
# <h4> Observations: </h4> We see that there are not any missing values in the dataset, but there are Null values.

# %% [markdown]
# <h3> Step 3: </h3>
# <h4>Univariate Analysis </h4>-> PDF, Histograms, Boxplots, Countplots, etc.. <br>
# -	Find the outliers in each numerical column <br>
# -	Understand the probability and frequency distribution of each numerical column <br>
# -	Understand the frequency distribution of each categorical Variable/Column <br>
# -	Mention observations after each plot.

# %% [markdown]
# ### Univariate Analysis of Continous Variables:   PDF, Histograms, Boxplots.

# %% [markdown]
# #### 1) Univariate Analysis on ID Column:

# %%
# PDF
pdf = stats.norm.pdf(df['ID'].sort_values(), np.mean(df['ID']), np.std(df['ID']))
plt.plot(df["ID"].sort_values(), pdf, color = 'g')
plt.xlabel("ID", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['ID'])
# Out:
# <AxesSubplot:xlabel='ID', ylabel='Count'>

# %%
# BOXPLOT
df['ID'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:** There is not any skeweness and there are no Outliers in the ID column.

# %% [markdown]
# #### 2) Univariate Analysis on Salary Column:

# %%
# PDF
pdf = stats.norm.pdf(df['Salary'].sort_values(), np.mean(df['Salary']), np.std(df['Salary']))
plt.plot(df["Salary"].sort_values(), pdf, color = 'g')
plt.xlabel("Salary", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
df['Salary'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# BOXPLOT
df['Salary'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The Salary of employees are positively skewed and there are Outliers in the column.

# %% [markdown]
# #### 3) Univariate Analysis on 10percentage Column:

# %%
# PDF
pdf = stats.norm.pdf(df['10percentage'].sort_values(), np.mean(df['10percentage']), np.std(df['10percentage']))
plt.plot(df["10percentage"].sort_values(), pdf, color = 'g')
plt.xlabel("10percentage", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['10percentage'])
# Out:
# <AxesSubplot:xlabel='10percentage', ylabel='Count'>

# %%
# BOXPLOT
df['10percentage'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The 10th percentage of employees are negatively skewed and there are Outliers in the column.

# %% [markdown]
# #### 4) Univariate Analysis on 12graduation Column:

# %%
# PDF
pdf = stats.norm.pdf(df['12graduation'].sort_values(), np.mean(df['12graduation']), np.std(df['12graduation']))
plt.plot(df["12graduation"].sort_values(), pdf, color = 'g')
plt.xlabel("12graduation", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['12graduation'])
# Out:
# <AxesSubplot:xlabel='12graduation', ylabel='Count'>

# %%
# BOXPLOT
df['12graduation'].plot.box()
# Out:
# <AxesSubplot:>

# %%
# COUNTPLOT
sns.countplot(y='12graduation', data = df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='12graduation'>

# %% [markdown]
# **Observations:**  The 12th Graduation year of employees are negatively skewed and there are Outliers in the column.

# %% [markdown]
# #### 5) Univariate Analysis on 12percentage Column:

# %%
# PDF
pdf = stats.norm.pdf(df['12percentage'].sort_values(), np.mean(df['12percentage']), np.std(df['12percentage']))
plt.plot(df["12percentage"].sort_values(), pdf, color = 'g')
plt.xlabel("12percentage", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['12percentage'])
# Out:
# <AxesSubplot:xlabel='12percentage', ylabel='Count'>

# %%
# BOXPLOT
df['12percentage'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The 12th percentage of employees are little negatively skewed and there is one Outlier in the column.

# %% [markdown]
# #### 6) Univariate Analysis on CollegeID Column:

# %%
# PDF
pdf = stats.norm.pdf(df['CollegeID'].sort_values(), np.mean(df['CollegeID']), np.std(df['CollegeID']))
plt.plot(df["CollegeID"].sort_values(), pdf, color = 'g')
plt.xlabel("CollegeID", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['CollegeID'])
# Out:
# <AxesSubplot:xlabel='CollegeID', ylabel='Count'>

# %%
# BOXPLOT
df['CollegeID'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The CollegeID of employees are little positevely skewed but there are no Outlier in the column.

# %% [markdown]
# #### 7) Univariate Analysis on collegeGPA Column:

# %%
# PDF
pdf = stats.norm.pdf(df['collegeGPA'].sort_values(), np.mean(df['collegeGPA']), np.std(df['collegeGPA']))
plt.plot(df["collegeGPA"].sort_values(), pdf, color = 'g')
plt.xlabel("collegeGPA", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['collegeGPA'])
# Out:
# <AxesSubplot:xlabel='collegeGPA', ylabel='Count'>

# %%
# BOXPLOT
df['collegeGPA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The CollegeGPA of employees have no skeweness but there are Outliers in the column.

# %% [markdown]
# #### 8) Univariate Analysis on CollegeCityID Column:

# %%
# PDF
pdf = stats.norm.pdf(df['CollegeCityID'].sort_values(), np.mean(df['CollegeCityID']), np.std(df['CollegeCityID']))
plt.plot(df["CollegeCityID"].sort_values(), pdf, color = 'g')
plt.xlabel("CollegeCityID", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['CollegeCityID'])
# Out:
# <AxesSubplot:xlabel='CollegeCityID', ylabel='Count'>

# %%
# BOXPLOT
df['CollegeCityID'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The CollegeCityID of employees are little positevely skewed but there are no Outlier in the column.

# %% [markdown]
# #### 9) Univariate Analysis on GraduationYear Column:

# %%
df['GraduationYear'].value_counts()
# Out:
# 2013    1181
# 2014    1036
# 2012     847
# 2011     507
# 2010     292
# 2015      94
# 2009      24
# 2017       8
# 2016       7
# 0          1
# 2007       1
# Name: GraduationYear, dtype: int64

# %%
# There is only one Missing Value, So replacing missing value with the most frequent value.
df['GraduationYear'].replace(0, 2013, inplace = True)

# %%
# PDF
pdf = stats.norm.pdf(df['GraduationYear'].sort_values(), np.mean(df['GraduationYear']), np.std(df['GraduationYear']))
plt.plot(df["GraduationYear"].sort_values(), pdf, color = 'g')
plt.xlabel("GraduationYear", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['GraduationYear'])
# Out:
# <AxesSubplot:xlabel='GraduationYear', ylabel='Count'>

# %%
# BOXPLOT
df['GraduationYear'].plot.box()
# Out:
# <AxesSubplot:>

# %%
# COUNTPLOT
sns.countplot(x='GraduationYear', data = df)
# Out:
# <AxesSubplot:xlabel='GraduationYear', ylabel='count'>

# %% [markdown]
# **Observations:**  The GraduationYear of employees have no skeweness but there is one Outlier in the column.

# %% [markdown]
# #### 10) Univariate Analysis on English Column:

# %%
# PDF
pdf = stats.norm.pdf(df['English'].sort_values(), np.mean(df['English']), np.std(df['English']))
plt.plot(df["English"].sort_values(), pdf, color = 'g')
plt.xlabel("English", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['English'])
# Out:
# <AxesSubplot:xlabel='English', ylabel='Count'>

# %%
# BOXPLOT
df['English'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The English of employees have no skeweness but there are Outliers in the column.

# %% [markdown]
# #### 11) Univariate Analysis on Logical Column:

# %%
# PDF
pdf = stats.norm.pdf(df['Logical'].sort_values(), np.mean(df['Logical']), np.std(df['Logical']))
plt.plot(df["Logical"].sort_values(), pdf, color = 'g')
plt.xlabel("Logical", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['Logical'])
# Out:
# <AxesSubplot:xlabel='Logical', ylabel='Count'>

# %%
# BOXPLOT
df['Logical'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The Logic of employees have no skeweness but there are Outliers in the column.

# %% [markdown]
# #### 12) Univariate Analysis on Quant Column:

# %%
# PDF
pdf = stats.norm.pdf(df['Quant'].sort_values(), np.mean(df['Quant']), np.std(df['Quant']))
plt.plot(df["Quant"].sort_values(), pdf, color = 'g')
plt.xlabel("Quant", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['Quant'])
# Out:
# <AxesSubplot:xlabel='Quant', ylabel='Count'>

# %%
# BOXPLOT
df['Quant'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The Quant of employees have no skeweness but there are Outliers in the column.

# %% [markdown]
# #### 13) Univariate Analysis on Domain Column:

# %%
# PDF
pdf = stats.norm.pdf(df['Domain'].sort_values(), np.mean(df['Domain']), np.std(df['Domain']))
plt.plot(df["Domain"].sort_values(), pdf, color = 'g')
plt.xlabel("Domain", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['Domain'])
# Out:
# <AxesSubplot:xlabel='Domain', ylabel='Count'>

# %%
# BOXPLOT
df['Domain'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The Domain knowledge of employees is nigatively skewened and there are Missing Values in the column.

# %% [markdown]
# #### 14) Univariate Analysis on ComputerProgramming Column:

# %%
# PDF
pdf = stats.norm.pdf(df['ComputerProgramming'].sort_values(), np.mean(df['ComputerProgramming']), np.std(df['ComputerProgramming']))
plt.plot(df["ComputerProgramming"].sort_values(), pdf, color = 'g')
plt.xlabel("ComputerProgramming", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['ComputerProgramming'])
# Out:
# <AxesSubplot:xlabel='ComputerProgramming', ylabel='Count'>

# %%
# BOXPLOT
df['ComputerProgramming'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The ComputerProgramming subject of employees have no skeweness but there are Outliers and a lot of missing values in the column.

# %% [markdown]
# #### 15) Univariate Analysis on ElectronicsAndSemicon Column:

# %%
# PDF
pdf = stats.norm.pdf(df['ElectronicsAndSemicon'].sort_values(), np.mean(df['ElectronicsAndSemicon']), np.std(df['ElectronicsAndSemicon']))
plt.plot(df["ElectronicsAndSemicon"].sort_values(), pdf, color = 'g')
plt.xlabel("ElectronicsAndSemicon", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['ElectronicsAndSemicon'])
# Out:
# <AxesSubplot:xlabel='ElectronicsAndSemicon', ylabel='Count'>

# %%
# BOXPLOT
df['ElectronicsAndSemicon'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The ElectronicsAndSemicon Subject of employees is highly positevely skewened and there are Outliers in the column.

# %% [markdown]
# #### 16) Univariate Analysis on ComputerScience Column:

# %%
# PDF
pdf = stats.norm.pdf(df['ComputerScience'].sort_values(), np.mean(df['ComputerScience']), np.std(df['ComputerScience']))
plt.plot(df["ComputerScience"].sort_values(), pdf, color = 'g')
plt.xlabel("ComputerScience", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['ComputerScience'])
# Out:
# <AxesSubplot:xlabel='ComputerScience', ylabel='Count'>

# %%
# BOXPLOT
df['ComputerScience'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The ComputerScience Subject of employees is highly positevely skewened and there are Outliers in the column.

# %% [markdown]
# #### 17) Univariate Analysis on MechanicalEngg Column:

# %%
# PDF
pdf = stats.norm.pdf(df['MechanicalEngg'].sort_values(), np.mean(df['MechanicalEngg']), np.std(df['MechanicalEngg']))
plt.plot(df["MechanicalEngg"].sort_values(), pdf, color = 'g')
plt.xlabel("MechanicalEngg", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['MechanicalEngg'])
# Out:
# <AxesSubplot:xlabel='MechanicalEngg', ylabel='Count'>

# %%
# BOXPLOT
df['MechanicalEngg'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The MechanicalEngg Subject of employees are highly positively skewened and there are Outliers and a lot of missing values in the column.

# %% [markdown]
# #### 18) Univariate Analysis on ElectricalEngg Column:

# %%
# PDF
pdf = stats.norm.pdf(df['ElectricalEngg'].sort_values(), np.mean(df['ElectricalEngg']), np.std(df['ElectricalEngg']))
plt.plot(df["ElectricalEngg"].sort_values(), pdf, color = 'g')
plt.xlabel("ElectricalEngg", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['ElectricalEngg'])
# Out:
# <AxesSubplot:xlabel='ElectricalEngg', ylabel='Count'>

# %%
# BOXPLOT
df['ElectricalEngg'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The ElectricalEngg Subject of employees are highly positively skewened and there are Outliers and a lot of missing values in the column.

# %% [markdown]
# #### 19) Univariate Analysis on TelecomEngg Column:

# %%
# PDF
pdf = stats.norm.pdf(df['TelecomEngg'].sort_values(), np.mean(df['TelecomEngg']), np.std(df['TelecomEngg']))
plt.plot(df["TelecomEngg"].sort_values(), pdf, color = 'g')
plt.xlabel("TelecomEngg", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['TelecomEngg'])
# Out:
# <AxesSubplot:xlabel='TelecomEngg', ylabel='Count'>

# %%
# BOXPLOT
df['TelecomEngg'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The TelecomEngg Subject of employees are highly positively skewened and there are Outliers and a lot of missing values in the column.

# %% [markdown]
# #### 20) Univariate Analysis on CivilEngg Column:

# %%
# PDF
pdf = stats.norm.pdf(df['CivilEngg'].sort_values(), np.mean(df['CivilEngg']), np.std(df['CivilEngg']))
plt.plot(df["CivilEngg"].sort_values(), pdf, color = 'g')
plt.xlabel("CivilEngg", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['CivilEngg'])
# Out:
# <AxesSubplot:xlabel='CivilEngg', ylabel='Count'>

# %%
# BOXPLOT
df['CivilEngg'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The CivilEngg Subject of employees are highly positively skewened and there are Outliers and a lot of missing values in the column.

# %% [markdown]
# #### 21) Univariate Analysis on conscientiousness Column:

# %%
# PDF
pdf = stats.norm.pdf(df['conscientiousness'].sort_values(), np.mean(df['conscientiousness']), np.std(df['conscientiousness']))
plt.plot(df["conscientiousness"].sort_values(), pdf, color = 'g')
plt.xlabel("conscientiousness", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['conscientiousness'])
# Out:
# <AxesSubplot:xlabel='conscientiousness', ylabel='Count'>

# %%
# BOXPLOT
df['conscientiousness'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The conscientiousness of employees are little negatively skewened and there are Outliers in the column.

# %% [markdown]
# #### 22) Univariate Analysis on agreeableness Column:

# %%
# PDF
pdf = stats.norm.pdf(df['agreeableness'].sort_values(), np.mean(df['agreeableness']), np.std(df['agreeableness']))
plt.plot(df["agreeableness"].sort_values(), pdf, color = 'g')
plt.xlabel("agreeableness", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['agreeableness'])
# Out:
# <AxesSubplot:xlabel='agreeableness', ylabel='Count'>

# %%
# BOXPLOT
df['agreeableness'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The agreeableness of employees are little negatively skewened and there are Outliers in the column.

# %% [markdown]
# #### 23) Univariate Analysis on extraversion Column:

# %%
# PDF
pdf = stats.norm.pdf(df['extraversion'].sort_values(), np.mean(df['extraversion']), np.std(df['extraversion']))
plt.plot(df["extraversion"].sort_values(), pdf, color = 'g')
plt.xlabel("extraversion", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['extraversion'])
# Out:
# <AxesSubplot:xlabel='extraversion', ylabel='Count'>

# %%
# BOXPLOT
df['extraversion'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The extraversion of employees are little negatively skewened and there are Outliers in the column.

# %% [markdown]
# #### 24) Univariate Analysis on nueroticism Column:

# %%
# PDF
pdf = stats.norm.pdf(df['nueroticism'].sort_values(), np.mean(df['nueroticism']), np.std(df['nueroticism']))
plt.plot(df["nueroticism"].sort_values(), pdf, color = 'g')
plt.xlabel("nueroticism", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['nueroticism'])
# Out:
# <AxesSubplot:xlabel='nueroticism', ylabel='Count'>

# %%
# BOXPLOT
df['nueroticism'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The nueroticism of employees are little positively skewened and there are Outliers in the column.

# %% [markdown]
# #### 25) Univariate Analysis on openess_to_experience Column:

# %%
# PDF
pdf = stats.norm.pdf(df['openess_to_experience'].sort_values(), np.mean(df['openess_to_experience']), np.std(df['openess_to_experience']))
plt.plot(df["openess_to_experience"].sort_values(), pdf, color = 'g')
plt.xlabel("openess_to_experience", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
# HISTOGRAM
sns.histplot(df['openess_to_experience'])
# Out:
# <AxesSubplot:xlabel='openess_to_experience', ylabel='Count'>

# %%
# BOXPLOT
df['openess_to_experience'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The openess_to_experience of employees are little negatively skewened and there are Outliers in the column.

# %% [markdown]
# ### Univariate Analysis of Categorical Variables:   Frequency Table, Barplots, Countplots.

# %% [markdown]
# #### 1) Univariate Analysis on Designation Column:

# %%
# Frequecy Table
df['Designation'].value_counts().head()
# Out:
# software engineer     539
# software developer    265
# system engineer       205
# programmer analyst    139
# systems engineer      118
# Name: Designation, dtype: int64

# %%
# BARPLOT
df['Designation'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The highest number of employees work as Software Engineer Designation followed by Software Developer and System Engineer.

# %% [markdown]
# #### 2) Univariate Analysis on JobCity Column:

# %%
# Frequecy Table
df['JobCity'].value_counts().head()
# Out:
# Bangalore    627
# -1           461
# Noida        368
# Hyderabad    335
# Pune         290
# Name: JobCity, dtype: int64

# %%
# BARPLOT
df['JobCity'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The highest number of employees work in Bangalore City followed by Noida and Hyderabad. Also, there are null values in the column.

# %% [markdown]
# #### 3) Univariate Analysis on Gender Column:

# %%
# Frequecy Table
df['Gender'].value_counts()
# Out:
# m    3041
# f     957
# Name: Gender, dtype: int64

# %%
# COUNTPLOT
sns.countplot(x='Gender', data = df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# **Observations:**  The Male count of employees is almost thrice the number of Female count.

# %% [markdown]
# #### 4) Univariate Analysis on 10board Column:

# %%
# Frequency Table
df['10board'].value_counts().head()
# Out:
# cbse           1395
# state board    1164
# 0               350
# icse            281
# ssc             122
# Name: 10board, dtype: int64

# %%
# BARPLOT
df['10board'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The highest number of employees came from CBSC Board in 10th followed by State Board and ICSE. Also, there are null values in the column.

# %% [markdown]
# #### 5) Univariate Analysis on 12board Column:

# %%
# Frequency Table
df['12board'].value_counts().head()
# Out:
# cbse           1400
# state board    1254
# 0               359
# icse            129
# up board         87
# Name: 12board, dtype: int64

# %%
# BARPLOT
df['12board'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The highest number of employees came from CBSC Board in 12th followed by State Board and ICSE. Also, there are null values in the column.

# %% [markdown]
# #### 6) Univariate Analysis on CollegeTier Column:

# %%
# Frequency Table
df['CollegeTier'].value_counts()
# Out:
# 2    3701
# 1     297
# Name: CollegeTier, dtype: int64

# %%
# COUNTPLOT
sns.countplot(x='CollegeTier', data = df)
# Out:
# <AxesSubplot:xlabel='CollegeTier', ylabel='count'>

# %% [markdown]
# **Observations:**  Most of the Employees are from Tier 2 colleges.

# %% [markdown]
# #### 7) Univariate Analysis on Degree Column:

# %%
# Frequency Table
df['Degree'].value_counts()
# Out:
# B.Tech/B.E.      3700
# MCA               243
# M.Tech./M.E.       53
# M.Sc. (Tech.)       2
# Name: Degree, dtype: int64

# %%
# COUNTPLOT
sns.countplot(x='Degree', data = df)
# Out:
# <AxesSubplot:xlabel='Degree', ylabel='count'>

# %% [markdown]
# **Observations:**  Most of the Employees are from B.Tech/B.E Degree.

# %% [markdown]
# #### 8) Univariate Analysis on Specialization Column:

# %%
# Frequency Table
df['Specialization'].value_counts()
# Out:
# electronics and communication engineering      880
# computer science & engineering                 744
# information technology                         660
# computer engineering                           600
# computer application                           244
# mechanical engineering                         201
# electronics and electrical engineering         196
# electronics & telecommunications               121
# electrical engineering                          82
# electronics & instrumentation eng               32
# civil engineering                               29
# electronics and instrumentation engineering     27
# information science engineering                 27
# instrumentation and control engineering         20
# electronics engineering                         19
# biotechnology                                   15
# other                                           13
# industrial & production engineering             10
# ...

# %%
# BARPLOT
df['Specialization'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The highest number of employees came from 'Electronics & Communication Engineering' followed by 'Computer Science & Engineering' and 'Information Technology'.

# %% [markdown]
# #### 9) Univariate Analysis on CollegeCityTier Column:

# %%
# Frequency Table
df['CollegeCityTier'].value_counts()
# Out:
# 0    2797
# 1    1201
# Name: CollegeCityTier, dtype: int64

# %%
# COUNTPLOT
sns.countplot(x='CollegeCityTier', data = df)
# Out:
# <AxesSubplot:xlabel='CollegeCityTier', ylabel='count'>

# %% [markdown]
# **Observations:**  Employees are from Tier 1 college City and there are Missing Values in the column.

# %% [markdown]
# #### 10) Univariate Analysis on CollegeState Column:

# %%
# Frequency Table
df['CollegeState'].value_counts()
# Out:
# Uttar Pradesh        915
# Karnataka            370
# Tamil Nadu           367
# Telangana            319
# Maharashtra          262
# Andhra Pradesh       225
# West Bengal          196
# Punjab               193
# Madhya Pradesh       189
# Haryana              180
# Rajasthan            174
# Orissa               172
# Delhi                162
# Uttarakhand          113
# Kerala                33
# Jharkhand             28
# Chhattisgarh          27
# Gujarat               24
# Himachal Pradesh      16
# Bihar                 10
# Jammu and Kashmir      7
# Assam                  5
# Union Territory        5
# Sikkim                 3
# Meghalaya              2
# Goa                    1
# Name: CollegeState, dtype: int64

# %%
# BARPLOT
df['CollegeState'].value_counts().head().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations:**  The highest number of employees completed their college from Uttar Pradesh City followed by Karnataka and Tamil Nadu.

# %% [markdown]
# <h3> Step 4: </h3> <h4> Bivariate Analysis:</h4>
# -	Discover the relationships between numerical columns using Scatter plots, hexbin plots, pair plots, etc.. <br>
# -	Identify the patterns between categorical and numerical columns using swarmplot, boxplot, barplot, etc.. <br>
# -	Mention observations after each plot..

# %% [markdown]
# ### Numerical - Numerical Bivariate Analysis:
# #### 1) Bivariate Analysis on Salary and 10percentage Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['10percentage'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='10percentage'>

# %%
# Correlation
sns.heatmap(df[['Salary', '10percentage']].corr())
df['Salary'].corr(df['10percentage'])
# Out:
# 0.17737277344849336

# %% [markdown]
# **Observations:**  There is no relation between Salary and 10percentage column.

# %% [markdown]
# #### 2) Bivariate Analysis on Salary and 12graduation Column:

# %%
# Scatter Plot
sns.scatterplot(y = df['Salary'], x = df['12graduation'], data = df)
# Out:
# <AxesSubplot:xlabel='12graduation', ylabel='Salary'>

# %%
# Correlation
sns.heatmap(df[['Salary', '12graduation']].corr())
df['Salary'].corr(df['12graduation'])
# Out:
# -0.16138253540849326

# %% [markdown]
# **Observations:**  There is no relation between Salary and 12graduation column.

# %% [markdown]
# #### 3) Bivariate Analysis on Salary and 12percentage Column:

# %%
# Correlation
sns.heatmap(df[['Salary', '12percentage']].corr())
df['Salary'].corr(df['12percentage'])
# Out:
# 0.170254477902461

# %% [markdown]
# **Observations:**  There is no relation between Salary and 12percentage column.

# %% [markdown]
# #### 4) Bivariate Analysis on Salary and CollegeTier Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['CollegeTier'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='CollegeTier'>

# %%
# Correlation
sns.heatmap(df[['Salary', 'CollegeTier']].corr())
df['Salary'].corr(df['CollegeTier'])
# Out:
# -0.17933210878954006

# %% [markdown]
# **Observations:**  There is no relation between Salary and 12graduation CollegeTier column.

# %% [markdown]
# #### 5) Bivariate Analysis on Salary and collegeGPA Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['collegeGPA'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='collegeGPA'>

# %%
# Correlation
sns.heatmap(df[['Salary', 'collegeGPA']].corr())
df['Salary'].corr(df['collegeGPA'])
# Out:
# 0.13010251907112563

# %% [markdown]
# **Observations:**  There is no relation between Salary and collegeGPA column.

# %% [markdown]
# #### 6) Bivariate Analysis on Salary and GraduationYear Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['GraduationYear'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='GraduationYear'>

# %%
# Correlation
sns.heatmap(df[['Salary', 'GraduationYear']].corr())
df['Salary'].corr(df['GraduationYear'])
# Out:
# -0.2123388165163323

# %% [markdown]
# **Observations:**  There is no relation between Salary and GraduationYear column.

# %% [markdown]
# #### 7) Bivariate Analysis on Salary and English Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['English'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='English'>

# %%
# Correlation
sns.heatmap(df[['Salary', 'English']].corr())
df['Salary'].corr(df['English'])
# Out:
# 0.17821904497537108

# %% [markdown]
# **Observations:**  There is no relation between Salary and English column.

# %% [markdown]
# #### 8) Bivariate Analysis on Salary and Logical Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['Logical'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Logical'>

# %%
# Correlation
sns.heatmap(df[['Salary', 'Logical']].corr())
df['Salary'].corr(df['Logical'])
# Out:
# 0.17927496648308655

# %% [markdown]
# **Observations:**  There is no relation between Salary and Logical column.

# %% [markdown]
# #### 9) Bivariate Analysis on Salary and Quant Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['Quant'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Quant'>

# %%
# Correlation
sns.heatmap(df[['Salary', 'Quant']].corr())
df['Salary'].corr(df['Quant'])
# Out:
# 0.23062742818671128

# %% [markdown]
# **Observations:**  There is no relation between Salary and Quant column.

# %% [markdown]
# #### 10) Bivariate Analysis on Salary and Domain Column:

# %%
# Scatter Plot
sns.scatterplot(x = df['Salary'], y = df['Domain'], data = df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Domain'>

# %%
# Correlation
sns.heatmap(df[['Salary', 'Domain']].corr())
df['Salary'].corr(df['Domain'])
# Out:
# 0.10465553709775705

# %% [markdown]
# **Observations:**  There is no relation between Salary and Domain column.

# %% [markdown]
# ### Categorial and Numerical Bivariate Analysis:
# #### 1) Bivariate Analysis on Salary and Designation Column:

# %%
# BARPLOT
df.groupby('Designation')['Salary'].mean().sort_values(ascending = False).head().plot.bar()
# Out:
# <AxesSubplot:xlabel='Designation'>

# %% [markdown]
# **Observations:**  The mean Salary of Junior Manager Designation is the highest followed by the senior developer and data scientist.

# %% [markdown]
# #### 2) Bivariate Analysis on Salary and JobCity Column:

# %%
# BARPLOT
df.groupby('JobCity')['Salary'].mean().sort_values(ascending = False).head().plot.bar()
# Out:
# <AxesSubplot:xlabel='JobCity'>

# %% [markdown]
# **Observations:**  The mean Salary of Kalmar, Sweden is the highest followed by the London and Johannesburg.

# %% [markdown]
# #### 3) Bivariate Analysis on Salary and Gender Column:

# %%
# BARPLOT
df.groupby('Gender')['Salary'].mean().sort_values(ascending = False).head().plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender'>

# %% [markdown]
# **Observations:**  The mean Salary of Male are little higher than the Female.

# %% [markdown]
# #### 4) Bivariate Analysis on Salary and Degree Column:

# %%
# BARPLOT
df.groupby('Degree')['Salary'].mean().sort_values(ascending = False).head().plot.bar()
# Out:
# <AxesSubplot:xlabel='Degree'>

# %% [markdown]
# **Observations:**  The mean Salary of M.Tech/M.E Degree are higher followed by the M.Sc(Tech) and B.Tech/B.E.

# %% [markdown]
# #### 5) Bivariate Analysis on Salary and Specialization Column:

# %%
# BARPLOT
df.groupby('Specialization')['Salary'].mean().sort_values(ascending = False).head().plot.bar()
# Out:
# <AxesSubplot:xlabel='Specialization'>

# %% [markdown]
# **Observations:**  The mean Salary of Polymer Technology Specialization are higher followed by the Computer Networking and Information Science.

# %% [markdown]
# <h3> Step 5:</h3>

# %% [markdown]
# #### Research Questions:
# #### 1) Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.” Test this claim with the data given to you.

# %%
df.head(3)
# Out:
#   Unnamed: 0      ID  Salary        DOJ      DOL              Designation  \
# 0      train  203097  420000 2012-06-01  present  senior quality engineer
# 1      train  579905  500000 2013-09-01  present        assistant manager
# 2      train  810601  325000 2014-06-01  present         systems engineer
#
#      JobCity Gender        DOB  10percentage                         10board  \
# 0  Bangalore      f 1990-02-19          84.3  board ofsecondary education,ap
# 1     Indore      m 1989-10-04          85.4                            cbse
# 2    Chennai      f 1992-08-03          85.0                            cbse
#
#    12graduation  12percentage                             12board  CollegeID  \
# 0          2007          95.8  board of intermediate education,ap       1141
# 1          2007          85.0                                cbse       5807
# 2          2010          68.2                                cbse         64
#
# ...

# %%
cs_df = df[['Specialization','Designation','Salary']][df['Specialization']=='computer science & engineering']
cs_df.reset_index(drop=True, inplace=True)
cs_df.shape
# Out:
# (744, 3)

# %%
cs_df.head(3)
# Out:
#                    Specialization             Designation  Salary
# 0  computer science & engineering  java software engineer  300000
# 1  computer science & engineering     data entry operator  120000
# 2  computer science & engineering      programmer analyst  335000

# %%
cs_df = cs_df[(cs_df['Designation']=='programmer analyst') | (cs_df['Designation']=='software engineer') | (cs_df['Designation']=='associate engineer')]
cs_df.reset_index(drop=True, inplace=True)
cs_df.shape
# Out:
# (167, 3)

# %%
cs_df.head(3)
# Out:
#                    Specialization         Designation  Salary
# 0  computer science & engineering  programmer analyst  335000
# 1  computer science & engineering   software engineer  340000
# 2  computer science & engineering   software engineer  390000

# %%
cs_df['Designation'].value_counts()
# Out:
# software engineer     139
# programmer analyst     26
# associate engineer      2
# Name: Designation, dtype: int64

# %%
pd.DataFrame(round(cs_df.groupby('Designation')['Salary'].mean(),2))
# Out:
#                        Salary
# Designation
# associate engineer  332500.00
# programmer analyst  323846.15
# software engineer   332949.64

# %%
# BARPLOT
cs_df.groupby('Designation')['Salary'].mean().sort_values(ascending = False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Designation'>

# %% [markdown]
# #### 2) Is there a relationship between gender and specialisation? (i.e. Does the preference of Specialisation depend on the Gender?)

# %%
pd.DataFrame(df.groupby('Specialization')['Gender'].value_counts()).head()
# Out:
#                                                 Gender
# Specialization                          Gender
# aeronautical engineering                m            2
#                                         f            1
# applied electronics and instrumentation m            7
#                                         f            2
# automobile/automotive engineering       m            5

# %% [markdown]
# <h3> Step 6:</h3>

# %% [markdown]
# #### Conclusion:
# ***1) The claim by Times of India that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate” is Proved to be True after Analyzing the given data.*** <br><br>
# ***2) We observed that most of the Females prefer selecting their specializaton something related to CS or IT such as Computer Application, Computer Engineering, Computer Science & Engineering, Electronics and Communication Engineering, Information Technology.***

# %% [markdown]
# <h3> Step 7:</h3>
# <h4>Perform feature transformation:</h4> <br>
# -	For Numerical Features -> Do Column Standardization. <br>
# -	For Categorical -> if more than 2 categories, use dummy variables. Otherwise convert the feature to Binary.

# %%
df.shape
# Out:
# (3998, 39)

# %%
df = pd.get_dummies(df, columns = ['Designation', 'JobCity', '10board', '12board', 'Degree', 'Specialization', 'CollegeState'])

# %%
df.shape
# Out:
# (3998, 1481)

# %%
df['Gender'] = df['Gender'].map({'m' : 1, 'f' : 0})

# %%
df = df.drop(['Unnamed: 0','DOJ','DOL','DOB'], axis = 1)

# %%
df.shape
# Out:
# (3998, 1477)

# %%
df.head(3)
# Out:
#        ID  Salary  Gender  10percentage  12graduation  12percentage  \
# 0  203097  420000       0          84.3          2007          95.8
# 1  579905  500000       1          85.4          2007          85.0
# 2  810601  325000       0          85.0          2010          68.2
#
#    CollegeID  CollegeTier  collegeGPA  CollegeCityID  CollegeCityTier  \
# 0       1141            2       78.00           1141                0
# 1       5807            2       70.06           5807                0
# 2         64            2       70.00             64                0
#
#    GraduationYear  English  Logical  Quant    Domain  ComputerProgramming  \
# 0            2011      515      585    525  0.635979                  445
# 1            2012      695      610    780  0.960603                   -1
# 2            2014      615      545    370  0.450877                  395
#
#    ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  \
# ...

# %% [markdown]
# ***Therefore, We successfully Converted all the Categorical columns in numeric columns.***

# %% [markdown]
# #### 2) Doing Standardization on on the Numeric columns:

# %%
from sklearn import preprocessing
standardized_df = preprocessing.StandardScaler().fit(df).transform(df)

# %%
standardized_df[0:5]
# Out:
# array([[-1.2685353 ,  0.52794734, -1.78259318, ..., -0.5447833 ,
#         -0.17054685, -0.22705025],
#        [-0.23099069,  0.90404468,  0.56098049, ..., -0.5447833 ,
#         -0.17054685, -0.22705025],
#        [ 0.40423306,  0.08133175, -1.78259318, ...,  1.83559225,
#         -0.17054685, -0.22705025],
#        [-1.09134693,  3.72477469,  0.56098049, ..., -0.5447833 ,
#         -0.17054685, -0.22705025],
#        [-0.8818709 , -0.50632033,  0.56098049, ...,  1.83559225,
#         -0.17054685, -0.22705025]])

# %% [markdown]
# # Hence, Completed.
